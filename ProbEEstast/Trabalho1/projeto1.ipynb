# %% [markdown]
# # Projeto 1 de Probabilidade e Estatística
# Grupo: Ciro, Gabriel, Natany

# %% [markdown]
# ## INFO GERAL SOBRE OS DADOS:
# ### LOCAL ONDE ADQUIRIMOS: KAGGLE - LINK: https://www.kaggle.com/datasets/octopusteam/imdb-top-1000-movies?resource=download
# ### Variáveis Contínuas: averageRating, numVotes, releaseYear
# ### Variáveis Categóricas: id, title, genres
# ### Contexto: Filmes e cinema (entretenimento)

# %% [markdown]
# # 2)

# %% [markdown]
# # Dados que serão avaliados

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from scipy.stats import pearsonr

dados_df = pd.read_csv("C:/Users/cirog/source/SegundoAno/ProbEEstast/Trabalho1/filmes.csv") # trocar caminho referenciando o csv da maquina

# %% [markdown]
# # A) Estatísticas Descritivas:

# %% [markdown]
# ## Média

# %%
media_dados_df = dados_df['averageRating'].mean()
print("\nMédia:", media_dados_df)
# Out:
# Média: 8.136899999999999

# %% [markdown]
# ## Mediana

# %%
mediana_dados_df = dados_df['averageRating'].median()
print("\nMediana:", mediana_dados_df)
# Out:
# Mediana: 8.1

# %% [markdown]
# ## Moda

# %%
moda_dados_df = dados_df['averageRating'].mode().tolist()  
print("\nModa:", moda_dados_df)
# Out:
# Moda: [7.9]

# %% [markdown]
# ## Desvio Padrão

# %%
desvio_padrao_dados_df = dados_df[['averageRating']].std()
print("\nDesvio Padrão:", desvio_padrao_dados_df.to_string(index=False))
# Out:
# Desvio Padrão: 0.253836

# %% [markdown]
# ## Variância

# %%
variancia_dados_df = dados_df[['averageRating']].var()
print("\nVariância:", variancia_dados_df.to_string(index=False))
# Out:
# Variância: 0.064433

# %% [markdown]
# # B) Distribuição dos Dados:

# %% [markdown]
# ## Histograma

# %%
plt.hist(dados_df['averageRating'], color='red', alpha=0.7)
plt.title('Histograma da Média de Notas')
plt.xlabel('Média de Notas')
plt.ylabel('Frequência')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(dados_df['averageRating'], vert=True)
plt.title('Boxplot da Média de Notas')
plt.xlabel('Média de Notas')
plt.grid(axis='x', alpha=0.75)
plt.show()

# %% [markdown]
# # C) Correlação entre Variáveis

# %% [markdown]
# ## Correlação de Pearson

# %%
correlacao_person = dados_df['averageRating'].corr(dados_df['numVotes'])
print("\nCorrelação entre Média de Notas e Número de Votos:", correlacao_person)
# Out:
# Correlação entre Média de Notas e Número de Votos: 0.29386878794683874

# %% [markdown]
# ## Dispersão

# %%
plt.scatter(dados_df['numVotes'], dados_df['averageRating'], alpha=0.7, color='blue')
plt.title('Gráfico de Dispersão: Média de Notas vs. Número de Votos')
plt.xlabel('Número de Votos')
plt.ylabel('Média de Notas')
plt.grid(alpha=0.75)
plt.show()

# %% [markdown]
# # D) Regressão Linear

# %%
X = dados_df['numVotes'].values.reshape(-1, 1)
y = dados_df['averageRating'].values

model = LinearRegression()
model.fit(X, y)

# calcula o R²
r_squared = model.score(X, y)

# calcula o r
coef_pearson, p_valor = pearsonr(dados_df['numVotes'], dados_df['averageRating'])

y_pred = model.predict(X)

plt.figure(figsize=(8,6))
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, y_pred, color='red', label='Regression Line')

plt.xlabel('Número de votos')
plt.ylabel('Média de Notas')
plt.title('Regressão Lienar: Média de Notas vs. Número de Votos')
plt.legend()
plt.show()
print(f"O valor de R² é: {r_squared}")
print(f"O valor de r é: {coef_pearson}")
# Out:
# O valor de R² é: 0.08635886452934405
# O valor de r é: 0.293868787946839

# %% [markdown]
# # 3.

# %% [markdown]
# ## a) Descrição do Conjunto de Dados:

# %% [markdown]
# ### Descrição das variáveis

# %% [markdown]
# #### As variáveis quantitativas no conjunto de dados incluem, por exemplo, "Duração", "Ano de Lançamento" e "Nota IMDB", que são usadas para calcular medidas como média e desvio padrão. Já as variáveis qualitativas incluem "Gênero" e "Classificação Indicativa", que representam categorias distintas de informação.

# %% [markdown]
# ### Contexto dos dados:
# #### O conjunto de dados está relacionado ao contexto cinematográfico, contendo informações de filmes, suas durações, anos de lançamento, gêneros, e avaliações de público.

# %% [markdown]
# ## b) Resultados das Análises:

# %% [markdown]
# ### Resultados das estatísticas descritivas

# %% [markdown]
# #### Média: 8.136899999999999
# #### Mediana: 8.1
# #### Moda: 7.9
# #### Desvio Padrão: 0.253836

# %% [markdown]
# ### Gráficos

# %% [markdown]
# #### ![image.png](attachment:image.png)
# #### ![image-2.png](attachment:image-2.png)
# #### ![image-3.png](attachment:image-3.png)
# #### ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### Interpretação dos resultados

# %% [markdown]
# Comparando os dados resultantes dos graficos e tabelas, é evidente que a média das notas se aproxima do valor 8, ou seja, a maior parte das notas avaliadas, estão localizadas entre 8 e 8,5. Concluindo, uma nota próxima de 8 é a mais esperada de ser atribuida pelo público, e, diante o contexto, vemos que, independente do filme, sempre haverá notas positivas como negativas como o valor "r" nos mostra, ja que depende do gosto do expectador, porém ainda com isso, um filme mais bem avaliado, significa que pelo público, ele é mais apreciável.

# %% [markdown]
# ## c) Discussão da Correlação e Regressão:

# %% [markdown]
# A relação entre o número de votos "numVotes" e a nota média do filme "averageRatin" é positiva, pois a linha de regressão possui uma inclinação ascendente. Isso indica que, conforme o número de votos aumenta, a nota média tende a aumentar ligeiramente. Porém, a força da correlação é fraca, com valor 0.293868787946839. Esse resultado pode ser visualizado no gráfico também, visto que os pontos de dados estão bastante dispersos em torno da linha de regressão. O modelo sugere que a variável independente (número de votos) tem algum efeito sobre a variável dependente (nota média), mas a relação não é muito forte, conforme indicado pela dispersão dos pontos. O valor de R², que mede o quão bem a linha de regressão se ajusta aos dados, mostra um valor baixo de ajuste (0.08635886452934405), indicando que a variação no número de votos explica apenas uma pequena parte da variação na nota média. Isso sugere que outros fatores além do número de votos podem estar influenciando a avaliação dos filmes. Resumindo, há uma tendência positiva entre as variáveis, mas a correlação é fraca e o modelo de regressão linear não fornece uma explicação robusta para a variação nas notas médias dos filmes.

# %% [markdown]
# ### Resumo final dos resultados obtidos a partir da análise.

# %% [markdown]
# A análise dos dados de nosso projeto revelou a relação entre a média de notas e o número de votos. Os gráficos gerados mostraram que a maioria das médias de notas está concentrada em uma faixa específica, com poucos filmes recebendo notas extremas, indicando uma distribuição relativamente normal. A correlação entre a média de notas e o número de votos foi calculada e isso resultou em uma correlação positiva (normalmente entre 0.3 e 0.7) sugere que filmes com mais votos tendem a ter avaliações mais altas.

# %% [markdown]
# ### padrões ou tendências foram identificados

# %% [markdown]
# A média das notas apresenta uma distribuição normal, com a maioria dos filmes recebendo notas entre 5 e 8. A presença de outliers indica filmes com avaliações extremas. Além disso, existe uma correlação positiva entre a média de notas e o número de votos, sugerindo que filmes mais votados tendem a ter avaliações mais altas. A análise de regressão mostra que, à medida que o número de votos aumenta, a média das notas também tende a subir. É importante evitar interpretações errôneas que possam levar a correlações espúrias. Esses resultados podem ajudar estúdios e plataformas de streaming a compreender o que faz um filme ser bem avaliado, guiando assim a produção de novos conteúdos.
